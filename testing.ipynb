# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      |████████████████████████████████| 249 kB 5.5 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import pandas as pd

# %%
df = pd.read_excel(r"taxTables/2023.xlsx", sheet_name="STSL Statement of Formula - CSV")

# %%
df
# Out:
#      Tax Scale  Weekly Earnings Less Than  Component A Factor  \
# 0          1.0                       88.0              0.1900
# 1          1.0                      371.0              0.2348
# 2          1.0                      515.0              0.2190
# 3          1.0                      641.0              0.3477
# 4          1.0                      794.0              0.3577
# ..         ...                        ...                 ...
# 124        6.0                     2587.0              0.4650
# 125        6.0                     2743.0              0.4700
# 126        6.0                     2907.0              0.4750
# 127        6.0                     3461.0              0.4800
# 128        6.0                   999999.0              0.5600
#
#      Component B Factor
# 0                0.1900
# 1                3.9639
# 2               -1.9003
# 3               64.4297
# 4               64.4297
# ..                  ...
# 124            286.5965
# 125            286.5965
# 126            286.5965
# 127            286.5965
# 128            563.5196
#
# [129 rows x 4 columns]

# %%
grouped = df.groupby("Tax Scale")
grouped

# %%
need = grouped.get_group(1)

# %%
need
# Out:
#     Tax Scale  Weekly Earnings Less Than  Component A Factor  \
# 0         1.0                       88.0              0.1900
# 1         1.0                      371.0              0.2348
# 2         1.0                      515.0              0.2190
# 3         1.0                      641.0              0.3477
# 4         1.0                      794.0              0.3577
# 5         1.0                      863.0              0.3677
# 6         1.0                      932.0              0.3727
# 7         1.0                      936.0              0.3700
# 8         1.0                     1013.0              0.3750
# 9         1.0                     1095.0              0.3800
# 10        1.0                     1181.0              0.3850
# 11        1.0                     1273.0              0.3900
# 12        1.0                     1371.0              0.3950
# 13        1.0                     1474.0              0.4000
# 14        1.0                     1583.0              0.4050
# 15        1.0                     1699.0              0.4100
# 16        1.0                     1822.0              0.4150
# 17        1.0                     1953.0              0.4200
# 18        1.0                     1957.0              0.4250
# 19        1.0                     2091.0              0.4700
# 20        1.0                     2237.0              0.4750
# 21        1.0                     2393.0              0.4800
# 22        1.0                     2557.0              0.4850
# 23        1.0                     3111.0              0.4900
# 24        1.0                   999999.0              0.5700
#
#     Component B Factor
# 0               0.1900
# 1               3.9639
# 2              -1.9003
# 3              64.4297
# 4              64.4297
# 5              64.4297
# 6              64.4297
# 7              61.9132
# 8              61.9132
# 9              61.9132
# 10             61.9132
# 11             61.9132
# 12             61.9132
# 13             61.9132
# 14             61.9132
# 15             61.9132
# 16             61.9132
# 17             61.9132
# 18             61.9132
# 19            150.0093
# 20            150.0093
# 21            150.0093
# 22            150.0093
# 23            150.0093
# 24            398.9324
